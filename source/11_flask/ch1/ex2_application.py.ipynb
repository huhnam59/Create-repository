# %%
# 웹서버 생성 및 실행, url(/apt/2025/106/9) 요청시 집값
from flask import Flask
from predict import loaded_model, predict_apt_price

application = Flask(__name__) # 웹 서버(웹 어플리케이션 객체)
@application.route('/')
def handler_function():
  return "<h1>Hello</h1>"
@application.route('/apt/<year>/<square>/<floor>')
def aptPredictHandler(year, square, floor):
  answer = predict_apt_price(year, square, floor)
  return "<h1>예측 금액은 {}<h1>".format(answer)
if __name__=="__main__":
  application.run(debug=True) # 서버실행(소스 변경시 서버 자동 재시작)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 웹서버 생성 및 실행, url(/apt/2025/106/9) 요청시 집값
#       2 from flask import Flask
# ----> 3 from predict import loaded_model, predict_apt_price
#       5 application = Flask(__name__) # 웹 서버(웹 어플리케이션 객체)
#       6 @application.route('/')
#       7 def handler_function():
#
# File C:\ai\source\11_flask\ch1\predict.py:2
#       1 import joblib
# ----> 2 loaded_model = joblib.load('model/apt.joblib')
#       4 def predict_apt_price(year, square, floor):
#       5   input_data = [[int(year), int(square), int(floor), 1]]
#
# File ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py:587, in load(filename, mmap_mode)
#     581             if isinstance(fobj, str):
#     582                 # if the returned file object is a string, this means we
#     583                 # try to load a pickle file generated with an version of
#     584                 # Joblib so we load it with joblib compatibility function.
#     585                 return load_compatibility(fobj)
# --> 587             obj = _unpickle(fobj, filename, mmap_mode)
#     588 return obj
#
# File ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py:506, in _unpickle(fobj, filename, mmap_mode)
#     504 obj = None
#     505 try:
# --> 506     obj = unpickler.load()
#     507     if unpickler.compat_mode:
#     508         warnings.warn("The file '%s' has been generated with a "
#     509                       "joblib version less than 0.10. "
#     510                       "Please regenerate this pickle file."
#     511                       % filename,
#     512                       DeprecationWarning, stacklevel=3)
#
# File ~\anaconda3\lib\pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~\anaconda3\lib\pickle.py:1623, in _Unpickler.load_binget(self)
#    1621 except KeyError as exc:
#    1622     msg = f'Memo value not found at index {i}'
# -> 1623     raise UnpicklingError(msg) from None
#
# UnpicklingError: Memo value not found at index 147
