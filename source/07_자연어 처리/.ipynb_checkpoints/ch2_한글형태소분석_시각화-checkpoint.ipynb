# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch2. 한글 형태소 분석</span>
# # 1. 자연어처리
# - 자연어: 일상적인 언어
# - 자연어 처리 분야
#        * 자연어 이해: 형태소 분석-> pos tagging(품사태깅)-> 의미분석(빈도분석, 연관분석)
#        * 자연어 이해&생성: RUN/LSTM/GRU->seq2seq->트랜스포머
# - 활용분야: 트랜드분석, 탐색적 분석, 맞춤법검사, 번역기, 챗봇
# # 2. 자연어 이해/생성 처리 절차
# - 전처리: 단어/어절 추출(특수문자 ㅎㅎ제외)
# - 분석 후보 생성: 행태소분석, 품사태깅
# - 제약 조건: 불용어 처리(set), 규칙 확인
# - 분석: 시각화(워드클라우드, Text), 유사도 분석, 연관분석(사실상 잘 안 됨), RNN/LSTM/GUR, ....
# # 3.  형태소 분석 엔진
# - konlpy
#     * HanNanum: java로 만든 형태소 분석기(JAVA_HOME 환경변수, Path 설정)
#     * kkma: java로 만든 형태소 분석기(JAVA_HOME 환경변수, Path 설정)
#     * komoran: java로 만든 형태소 분석기(JAVA_HOME 환경변수, Path 설정)
#     * okt: java로 만든 형태소 분석기(JAVA_HOME 환경변수, Path 설정)
# - Mecab(pip install python-mecab-ko)
#     * Mecab: C++로 만든 형태소 분석기, 저사양환경에서 사용 가능
# - 공통기능: morphs(형태소 나누기), nouns(명사추출), pos(형태소로 나누어 품사테그)
#
# - pos tagging chat 다운로드:  "https://konlpy.org/en/latest/" 클릭
# - api 메뉴-> "Comparison between POS tagging classes" 클릭
# - "Korean POS tags comparison chart 다운로드

# %%
# %pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.6.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---- ----------------------------------- 2.1/19.4 MB 59.2 MB/s eta 0:00:01
#    ------------------ --------------------- 8.9/19.4 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 36.1 MB/s  0:00:00
# Downloading jpype1-1.6.0-cp310-cp310-win_amd64.whl (356 kB)
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 59.9 MB/s  0:00:00
# Installing collected packages: lxml, JPype1, konlpy
#
#    ---------------------------------------- 0/3 [lxml]
#    -------------------------- ------------- 2/3 [konlpy]
#    ---------------------------------------- 3/3 [konlpy]
#
# Successfully installed JPype1-1.6.0 konlpy-0.6.0 lxml-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-mecab-ko
# Out:
# Collecting python-mecab-ko
#   Downloading python_mecab_ko-1.3.7-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Collecting python-mecab-ko-dic (from python-mecab-ko)
#   Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl.metadata (1.4 kB)
# Downloading python_mecab_ko-1.3.7-cp310-cp310-win_amd64.whl (652 kB)
#    ---------------------------------------- 0.0/652.4 kB ? eta -:--:--
#    ---------------------------------------- 652.4/652.4 kB ?  0:00:00
# Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
#    ---------------------------------------- 0.0/34.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/34.5 MB 16.8 MB/s eta 0:00:02
#    ------- -------------------------------- 6.8/34.5 MB 19.1 MB/s eta 0:00:02
#    ------------------ --------------------- 16.3/34.5 MB 29.2 MB/s eta 0:00:01
#    --------------------------------- ------ 28.6/34.5 MB 37.0 MB/s eta 0:00:01
#    ---------------------------------------- 34.5/34.5 MB 37.7 MB/s  0:00:00
# Installing collected packages: python-mecab-ko-dic, python-mecab-ko
#
#    ---------------------------------------- 0/2 [python-mecab-ko-dic]
#    ---------------------------------------- 0/2 [python-mecab-ko-dic]
#    ---------------------------------------- 0/2 [python-mecab-ko-dic]
#    ---------------------------------------- 2/2 [python-mecab-ko]
#
# Successfully installed python-mecab-ko-1.3.7 python-mecab-ko-dic-2.1.1.post2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wordcloud # 1.3.7
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\Admin\anaconda3\envs\ml-dl-nlp\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip show wordcloud # 1.9.4
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages
# Requires: matplotlib, numpy, pillow
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gensim  # 4.4.0(워드임베딩=단어간 거리계산)
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from gensim) (1.15.3)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp310-cp310-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ------------ --------------------------- 7.3/24.4 MB 45.4 MB/s eta 0:00:01
#    ------------------------------ --------- 18.6/24.4 MB 48.9 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 48.3 MB/s  0:00:00
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Installing collected packages: smart_open, gensim
#
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show konlpy
# Out:
# Name: konlpy
# Version: 0.6.0
# Summary: Python package for Korean natural language processing.
# Home-page: http://konlpy.org
# Author: Team KoNLPy
# Author-email: konlpy@googlegroups.com
# License: GPL v3
# Location: c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages
# Requires: JPype1, lxml, numpy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show pyhon-mecab-ko
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: pyhon-mecab-ko

# %%
# %pip show wordcloud
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages
# Requires: matplotlib, numpy, pillow
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show gensim
# Out:
# Name: gensim
# Version: 4.4.0
# Summary: Python framework for fast Vector Space Modelling
# Home-page: https://radimrehurek.com/gensim/
# Author: Radim Rehurek
# Author-email: me@radimrehurek.com
# License: LGPL-2.1-only
# Location: c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages
# Requires: numpy, scipy, smart_open
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ.get('JAVA_HOME')
# Out:
# 'C:\\Program Files\\Java\\jdk-17'

# %%
import konlpy
konlpy.__version__ # 에러가 나는 경우
# Out:
# '0.6.0'

# %%
text="""아릅답지만 다소 복잡하긷고 한 한국어는 전 세계에서 13번째로 많이 사용되는 언어입니다"""

# %% [markdown]
# # 3.1 HanNanum

# %%
from konlpy.tag import Hannanum
hannanum=Hannanum(#jvmpath=None,max_heap_size=128
                 ) # 기본값:1024 '1g' '10m'
# 입력된 텍스트를 가장 세밀하게 분석해서 형태소, 품사, 원형등을 모두 반환
hannanum.analyze(text)
# Out:
# [[[('아릅답', 'ncn'), ('지만', 'jxc')],
#   [('아릅답지', 'ncn'), ('만', 'jxc')],
#   [('아릅답지만', 'ncn')],
#   [('아릅답', 'nqq'), ('지만', 'jxc')],
#   [('아릅답지', 'nqq'), ('만', 'jxc')],
#   [('아릅답지만', 'nqq')]],
#  [[('다소', 'mag')], [('다소', 'ncn')]],
#  [[('복잡하긷', 'ncn'), ('고', 'jcj')],
#   [('복잡하긷고', 'ncn')],
#   [('복잡하긷', 'nqq'), ('고', 'jcj')],
#   [('복잡하긷고', 'nqq')]],
#  [[('하', 'pvg'), ('ㄴ', 'etm')],
#   [('한', 'nnc')],
#   [('한', 'ncn')],
#   [('한', 'nbn')],
#   [('하', 'px'), ('ㄴ', 'etm')]],
#  [[('한국어', 'ncn'), ('는', 'jxc')]],
#  [[('전', 'mma')],
#   [('전', 'nbn')],
#   [('전', 'nbu')],
#   [('전', 'ncn')],
#   [('절', 'pvg'), ('ㄴ', 'etm')]],
#  [[('세계', 'ncn'), ('에서', 'jca')]],
#  [[('13', 'nnc'), ('번', 'nbu'), ('째', 'xsnu'), ('로', 'jca')]],
#  [[('많', 'paa'), ('이', 'xsa')], [('많이', 'mag')]],
#  [[('사용', 'ncpa'), ('되', 'xsvn'), ('는', 'etm')]],
#  [[('언어', 'ncn'), ('이', 'jp'), ('ㅂ니다', 'ef')]]]

# %%
# 형태소 분석: morphs
print(hannanum.morphs(text))
# Out:
# ['아릅답지', '만', '다소', '복잡하긷고', '하', 'ㄴ', '한국어', '는', '전', '세계', '에서', '13번', '째', '로', '많', '이', '사용', '되', '는', '언어', '이', 'ㅂ니다']

# %%
# 형태소 분석 : morphs
print(hannanum.morphs(text))
# Out:
# ['아릅답지', '만', '다소', '복잡하긷고', '하', 'ㄴ', '한국어', '는', '전', '세계', '에서', '13번', '째', '로', '많', '이', '사용', '되', '는', '언어', '이', 'ㅂ니다']

# %%
# 명사만 추출 : nouns
print(hannanum.nouns(text))
# Out:
# ['아릅답지', '복잡하긷고', '한국어', '전', '세계', '13번', '사용', '언어']

# %%
# 명사만 추출 : nouns
print(hannanum.nouns(text))
# Out:
# ['아릅답지', '복잡하긷고', '한국어', '전', '세계', '13번', '사용', '언어']

# %%
# 품사태그 : pos
print(hannanum.pos(text, ntags=9)) # 품사 갯수 기본값 : ntags=9
# Out:
# [('아릅답지', 'N'), ('만', 'J'), ('다소', 'M'), ('복잡하긷고', 'N'), ('하', 'P'), ('ㄴ', 'E'), ('한국어', 'N'), ('는', 'J'), ('전', 'N'), ('세계', 'N'), ('에서', 'J'), ('13번', 'N'), ('째', 'X'), ('로', 'J'), ('많', 'P'), ('이', 'X'), ('사용', 'N'), ('되', 'X'), ('는', 'E'), ('언어', 'N'), ('이', 'J'), ('ㅂ니다', 'E')]

# %%
print(hannanum.pos(text, ntags=22))
# Out:
# [('아릅답지', 'NC'), ('만', 'JX'), ('다소', 'MA'), ('복잡하긷고', 'NC'), ('하', 'PV'), ('ㄴ', 'ET'), ('한국어', 'NC'), ('는', 'JX'), ('전', 'NB'), ('세계', 'NC'), ('에서', 'JC'), ('13', 'NN'), ('번', 'NB'), ('째', 'XS'), ('로', 'JC'), ('많', 'PA'), ('이', 'XS'), ('사용', 'NC'), ('되', 'XS'), ('는', 'ET'), ('언어', 'NC'), ('이', 'JP'), ('ㅂ니다', 'EF')]

# %%
# 퀴즈1. pos tag 결과에서 명사(NC, NQ, NB, NN)만 추출하기
tagged_text = hannanum.pos(text, ntags=22)
[token for token, tag in tagged_text if tag in ('NC', 'NQ', 'NB', 'NN')]
# Out:
# ['아릅답지', '복잡하긷고', '한국어', '전', '세계', '13', '번', '사용', '언어']

# %%
# 퀴즈2. text에서 보통명사(NC)만 추출하기
[token for token, tag in tagged_text if tag =='NC']
# Out:
# ['아릅답지', '복잡하긷고', '한국어', '세계', '사용', '언어']

# %%
# 퀴즈3. text에서 형용사(PA)만 추출하기
[token for token, tag in tagged_text if tag =='PA']
# Out:
# ['많']

# %% [markdown]
# # 3.2 Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()
# 형태소 분석
print(kkma.morphs(text))
# Out:
# ['아릅답지', '만', '다소', '복', '잡하', '긷', '고', '하', 'ㄴ', '한국어', '는', '전', '세계', '에서', '13', '번째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다']

# %%
# 명사추출
print(kkma.nouns(text))
# Out:
# ['아릅답지', '복', '복잡하', '잡하', '한국어', '전', '세계', '13', '13번째', '번째', '사용', '언어']

# %%
# 품사태그
print(kkma.pos(text))
# Out:
# [('아릅답지', 'UN'), ('만', 'JX'), ('다소', 'MAG'), ('복', 'NNG'), ('잡하', 'UN'), ('긷', 'VV'), ('고', 'ECE'), ('하', 'VV'), ('ㄴ', 'ETD'), ('한국어', 'NNG'), ('는', 'JX'), ('전', 'NNG'), ('세계', 'NNG'), ('에서', 'JKM'), ('13', 'NR'), ('번째', 'NNB'), ('로', 'JKM'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN')]

# %%
# 품사태그를 통해 명사(NNG, NNP, NNB, NNM, NR, NP)만 추출
tagged_text = kkma.pos(text)
[token for token, tag in tagged_text if tag in ('NNG','NNP','NNB','NNM','NR','NP')]
# Out:
# ['복', '한국어', '전', '세계', '13', '번째', '사용', '언어']

# %%
# 품사태그를 통해 보통명사(NNG)만 추출
[token for token, tag in tagged_text if tag =='NNG' ]
# Out:
# ['복', '한국어', '전', '세계', '사용', '언어']

# %% [markdown]
# # 3.3 Komoran

# %%
text = """아름답지만 다소 복잡하기도 한 한국어는 전세계에서 13번째로 많이 사용되는 언어입니다"""

# %%
from konlpy.tag import Komoran
komoran = Komoran()
# 형태소 분석
print(komoran.morphs(text))
# Out:
# ['아릅답지만', '다소', '복잡', '하', '긷', '고', '한', '한국어', '는', '전', '세계', '에서', '13', '번', '째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다']

# %%
# 명사 추출
print(komoran.nouns(text))
# Out:
# ['하', '한국어', '세계', '번', '사용', '언어']

# %%
# 품사 태깅
tagged_text = komoran.pos(text)
print(tagged_text)
# Out:
# [('아릅답지만', 'NA'), ('다소', 'MAG'), ('복잡', 'XR'), ('하', 'NNG'), ('긷', 'VV'), ('고', 'EC'), ('한', 'MM'), ('한국어', 'NNP'), ('는', 'JX'), ('전', 'MM'), ('세계', 'NNG'), ('에서', 'JKB'), ('13', 'SN'), ('번', 'NNB'), ('째', 'XSN'), ('로', 'JKB'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EC')]

# %%
# 품사 태깅
tagged_text = komoran.pos(text)
print(tagged_text)
# Out:
# [('아릅답지만', 'NA'), ('다소', 'MAG'), ('복잡', 'XR'), ('하', 'NNG'), ('긷', 'VV'), ('고', 'EC'), ('한', 'MM'), ('한국어', 'NNP'), ('는', 'JX'), ('전', 'MM'), ('세계', 'NNG'), ('에서', 'JKB'), ('13', 'SN'), ('번', 'NNB'), ('째', 'XSN'), ('로', 'JKB'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EC')]

# %% [markdown]
# # 3.4 Twitter(Okt; Open Korean Text)
# - SNS 텍스트 분석용 개발
# - 속도가 빠름

# %%
# %%time
from mecab import MeCab
mecab = MeCab()
print('형태소 추출 :', mecab.morphs(text))
print('명사 추출 :', mecab.nouns(text))
tagged_text = mecab.pos(text)
print('품사 태깅을 이용한 명사 추출 :',
     [token for token, tag in tagged_text if tag in ('NNG','NNP', 'NNB', 'NNBC')]
     )
print('품사 태깅 :', tagged_text)
# Out:
# 형태소 추출 : ['아', '릅답', '지만', '다소', '복잡', '하', '긷', '고', '한', '한국어', '는', '전', '세계', '에서', '13', '번', '째', '로', '많이', '사용', '되', '는', '언어', '입니다']
# 명사 추출 : ['한국어', '세계', '번', '사용', '언어']
# 품사 태깅을 이용한 명사 추출 : ['한국어', '세계', '번', '사용', '언어']
# 품사 태깅 : [('아', 'IC'), ('릅답', 'UNKNOWN'), ('지만', 'EC'), ('다소', 'MAG'), ('복잡', 'XR'), ('하', 'XSA'), ('긷', 'VV'), ('고', 'EC'), ('한', 'MM'), ('한국어', 'NNG'), ('는', 'JX'), ('전', 'MM'), ('세계', 'NNG'), ('에서', 'JKB'), ('13', 'SN'), ('번', 'NNBC'), ('째', 'XSN'), ('로', 'JKB'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('언어', 'NNG'), ('입니다', 'VCP+EC')]
# CPU times: total: 15.6 ms
# Wall time: 7 ms

# %% [markdown]
# # 3.5 Mecab
# - pip install python-mecab-ko
# - 압도적 속도(konlpy 대비 5배~15배 빠름)
# - 낮은 메모리 사용량
# - 형태소 분해 정확도 높음

# %%
# %%time
from mecab import MeCab
mecab = MeCab()
print('형태소 추출 :', mecab.morphs(text))
print('명사 추출 :', mecab.nouns(text))
tagged_text = mecab.pos(text)
print('품사 태깅을 이용한 명사 추출 :',
     [token for token, tag in tagged_text if tag in ('NNG','NNP', 'NNB', 'NNBC')]
     )
print('품사 태깅 :', tagged_text)
# Out:
# 형태소 추출 : ['아', '릅답', '지만', '다소', '복잡', '하', '긷', '고', '한', '한국어', '는', '전', '세계', '에서', '13', '번', '째', '로', '많이', '사용', '되', '는', '언어', '입니다']
# 명사 추출 : ['한국어', '세계', '번', '사용', '언어']
# 품사 태깅을 이용한 명사 추출 : ['한국어', '세계', '번', '사용', '언어']
# 품사 태깅 : [('아', 'IC'), ('릅답', 'UNKNOWN'), ('지만', 'EC'), ('다소', 'MAG'), ('복잡', 'XR'), ('하', 'XSA'), ('긷', 'VV'), ('고', 'EC'), ('한', 'MM'), ('한국어', 'NNG'), ('는', 'JX'), ('전', 'MM'), ('세계', 'NNG'), ('에서', 'JKB'), ('13', 'SN'), ('번', 'NNBC'), ('째', 'XSN'), ('로', 'JKB'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('언어', 'NNG'), ('입니다', 'VCP+EC')]
# CPU times: total: 0 ns
# Wall time: 4.99 ms

# %% [markdown]
# # 4. 말뭉치

# %%
# 영어 말뭉치
import nltk
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
emma[:10]
# Out:
# '[Emma by J'

# %%
# 한글 말뭉치
from konlpy.corpus import kolaw
# data = kolaw.open('constitution.txt').readlines() # 한줄씩 list로 반환
data = kolaw.open('constitution.txt').read()
print('글자수 :',len(data))
# Out:
# 글자수 : 18884

# %% [markdown]
# # 5. 워드 클라우드
# - pip install wordcloud

# %%
nouns=['word1', 'word2', 'word1', 'word1']
' '.join(nouns)
# Out:
# 'word1 word2 word1 word1'

# %%
# emma 말뭉치에서 단어(특수문자를 제외) -> 명사(NN, NNS, NNP, NNPS)추출 -> 연결 -> 워드클라우드
from nltk.tokenize import RegexpTokenizer
from nltk.tag import pos_tag
# 단어들 추출
ret = RegexpTokenizer('[0-9a-zA-Z]{2,}')
words = ret.tokenize(emma)
# pos tagging -> 명사 추출
emma_tags = pos_tag(words)
noun_list = [token for token, tag in emma_tags if tag in ('NN', 'NNS', 'NNP', 'NNPS')]
# 연결
emma_noun = ' '.join(noun_list)
print('워드 클라우드를 그릴 text 내용 :', emma_noun[:20])
# Out:
# 워드 클라우드를 그릴 text 내용 : Emma Jane Austen VOL

# %%
# 워드 클라우드
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wordc = WordCloud()
wordc.generate(emma_noun)
plt.imshow(wordc)
plt.show()

# %% [markdown]
# - 컬러맵 : https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
wordcloud = WordCloud(
    font_path='C:/Windows/Fonts/comicz.ttf',
    background_color='white', # 배경색
    width=800, height=400, # 생성될 이미지 가로 세로(픽셀)
    max_words = 300, # 최대 표시될 단어 갯수
    relative_scaling=0.9, #단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    max_font_size=100, #최대 폰트 사이즈
    min_font_size=10, # 최소 폰트 사이즈
    random_state=42   # 결과를 일관되도록 그리기 위한 random seed값
)
wordcloud.generate(emma_noun)
#plt.figure(figsize=(20,7))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# data에서 명사추출 -> 연결 -> 워드클라우드
from konlpy.tag import Hannanum, Kkma, Komoran, Okt
from mecab import MeCab
analyzer = MeCab()
noun_list = analyzer.nouns(data)

# data 한글 말뭉치로 워드 count
from nltk import FreqDist
import pandas as pd
noun_wordcount = FreqDist(noun_list)
wordcnt = pd.Series(noun_wordcount)
wordcnt.sort_values(ascending=False, inplace=True)
wordcnt.head(20)
# Out:
# 조      136
# 법률     121
# 수       89
# 대통령     84
# 국가      73
# 국회      69
# 헌법      69
# 국민      69
# 때       55
# 바       37
# 필요      31
# 위원      30
# 기타      26
# 이       25
# 법원      25
# 보장      24
# 정부      23
# 사항      23
# 국무      23
# 항       22
# dtype: int64

# %%
# data에서 명사추출 -> 빈도수 파악
from konlpy.tag import Hannanum, Kkma, Komoran, Okt
from mecab import MeCab
analyzer = MeCab() # mecab, Kkma의 경우 NNG, NNP / Okt의 경우 None
# noun_list = analyzer.nouns(data)
noun_list = [word for word, tag in analyzer.pos(data) if tag in ('NNG', 'NNP')]
# data 한글 말뭉치로 워드 count
from nltk import FreqDist
import pandas as pd
noun_wordcount = FreqDist(noun_list)
wordcnt = pd.Series(noun_wordcount)
wordcnt.sort_values(ascending=False, inplace=True)
wordcnt.head(10)
# Out:
# 법률     121
# 대통령     84
# 조       79
# 국가      73
# 헌법      69
# 국민      69
# 국회      69
# 때       55
# 필요      31
# 위원      30
# dtype: int64

# %%
# data에서 명사추출 -> 연결 -> 워드클라우드
data_noun = ' '.join(noun_list)
print('명사 추출 :',noun_list[:5])
print('워드클라우드를 그릴 data :',data_noun[:20])
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='plasma', # 글씨 컬러맵
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# 명사 추출 : ['대한민국', '헌법', '역사', '전통', '국민']
# 워드클라우드를 그릴 data : 대한민국 헌법 역사 전통 국민 운동

# %%
# 불용어(불용어지정 + 불용어사전)
from wordcloud import STOPWORDS
불용어 = STOPWORDS | {'대통령', '조', '때', '항'} # | :집합 합 연산자
# a = {'네모','세모'}
# b = {'네모', '동그라미'}
# a|b
불용어 = {'대통령', '조', '때', '항'}
불용어
# Out:
# {'대통령', '때', '조', '항'}

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='plasma', # 글씨 컬러맵
    stopwords=불용어  # 불용어
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 이미지를 넘파이 배열로(방법1)
import cv2
mask = cv2.imread('data/test.png')
plt.figure(figsize=(2,1))
plt.imshow(mask)
type(mask), mask.shape # 3채널 이미지
# Out:
# (numpy.ndarray, (468, 720, 3))

# %%
# 이미지를 넘파이 배열로(방법2)
from PIL import Image
import numpy as np
img = Image.open('data/test.png')
mask = np.array(img)
plt.figure(figsize=(2,1))
plt.imshow(mask)
type(mask), mask.shape # 3채널 이미지
# Out:
# (numpy.ndarray, (468, 720, 3))

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    stopwords=불용어,  # 불용어
    mask=mask,
    contour_color='red', # 테두리 색상
    contour_width=1 # 테두리 두께
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# mask = cv2.imread('data/heart.jpg')
img = Image.open('data/heart.jpg')
mask = np.array(img)
plt.figure(figsize=(2, 1))
plt.imshow(mask, cmap='gray')
type(mask), mask.shape # 흑백이미지
# Out:
# (numpy.ndarray, (1600, 1600))

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    stopwords=불용어,  # 불용어
    mask=mask,
    # contour_color='red', # 테두리 색상
    # contour_width=1 # 테두리 두께
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# mask = cv2.imread('data/test2.jpg')
img = Image.open('data/test2.jpg')
mask = np.array(img)
plt.figure(figsize=(5, 5))
plt.imshow(mask)
type(mask), mask.shape # 3채널 컬러
# Out:
# (numpy.ndarray, (241, 257, 3))

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    stopwords=불용어,  # 불용어
    mask=mask,
   # contour_color='red', # 테두리 색상
   # contour_width=1 # 테두리 두께
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 이미지 전처리 : 옅은 회색->하얀색
# mask = cv2.imread('data/test2.jpg')
img = Image.open('data/test2.jpg')
mask = np.array(img)
mask.dtype
mask = np.where(mask>200, 255, 0).astype(np.uint8)
plt.figure(figsize=(5, 5))
plt.imshow(mask)
type(mask), mask.shape # 3채널 컬러
# Out:
# (numpy.ndarray, (241, 257, 3))

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    stopwords=불용어,  # 불용어
    mask=mask,
   contour_color='red', # 테두리 색상
   contour_width=1 # 테두리 두께
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 1채널이미지 -> 3채널 : convert('RGB')
img = Image.open('data/south_korea.png').convert('RGB')
mask = np.array(img)
plt.imshow(mask)
print(mask.shape)
# Out:
# (1124, 720, 3)

# %%
wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf', # 한글의 경우 폰트 설정 요망
    background_color='white',  # 배경색
    max_words=300,        # 표시될 단어의 최대 갯수
    #relative_scaling=0.6 # 단어 빈도에 따른 크기 차이 조정
    colormap='viridis', # 글씨 컬러맵
    stopwords=불용어,  # 불용어
    mask=mask,
   contour_color='red', # 테두리 색상
   contour_width=1 # 테두리 두께
)
wordcloud.generate(data_noun)
plt.figure(figsize=(18,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/korea.jpg') # jpg나 png

# %%
# 단어의 빈도수를 그래프로 시각화(nltk.Text)
import nltk
data_text = nltk.Text(noun_list)
plt.figure(figsize=(15,4))
plt.rc('font', family='Malgun Gothic') # 윈도우즈에서 한글 처리
data_text.plot(15)
plt.show()
