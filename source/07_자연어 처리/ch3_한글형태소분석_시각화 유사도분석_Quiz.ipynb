# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %% [markdown]
# # ※ Quiz: 경주여행과 전주여행에 대해 최빈단어시각화와 유사도 분석
# - (1) naver open API 를 활용하여 네이버지식인 "경주여행"과 "전주여행"을 각각 500건씩 검색 백업
#  * replace(), re.sum()이용
#  * 백업 파일 결과: 검색어, no, title, link, description, total_text(title+' '+description)
#
# - (2) 품사태깅 백업(naver_pos.csv)
#  * query, no, token, pos
# - (3) 명사만 추출 백업(naver_pos_nouns.csv)
#  *  query, no, token, pos
# - (4) 빈도분석 백업(naver_pos_nouns_count.csv)
#  * token, 경주빈도, 전주빈도, 빈도합
# - (5) 빈도 시각화(워드클라우드, Text.plot)
#   * 워드클라우드 이미지 저장
# - (6) 단어간 유사도 분석(Word2Vec, 연관분석)
# # 1. 네이버 open api 검색

# %%
# .env 가져오기(방법1) - 추천
from dotenv import load_dotenv
import os
load_dotenv()
# print(os.getenv('CLIENT_ID'))
# print(os.getenv('CLIENT_SECRET'))
# Out:
# True

# %%
# .env 가져오기(방법2)
from decouple import config
# print(config('CLIENT_ID'))
# print(config('CLIENT_SECRET'))

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
encText = urllib.parse.quote("경주 여행")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')[:200])
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 02 Dec 2025 15:13:27 +0900",
# 	"total":1003220,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"내 마음대로 기록하는 <b>경주여행<\/b> 2박3일",
# 			"link":"https:\/\/blog.naver.com\/hello

# %%
# 방법1
import requests
import pandas as pd
import json # response텍스트를 json스타일의 딕셔너리로
import re  # 정규표현식
from html import unescape # description에 &lt;등의 특수문자를 <(문자)로 변경

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
query = '경주 여행'
start = 1
headers = {
    'X-Naver-Client-Id':client_id,
    'X-Naver-Client-Secret':client_secret
}
# url = f'https://openapi.naver.com/v1/search/kin?query={query}&display=100&start={start}'
# response = requests.get(url, headers=headers)
url = 'https://openapi.naver.com/v1/search/kin'
params = {'query':query, 'display':100, 'start':start}
response = requests.get(url, params=params, headers=headers)
# print(response.text[:500])
# items = json.loads(response.text)['items']
items = response.json()['items']
print(len(items))
# Out:
# 100

# %%
# title, link, description 추출(b태그삭제, 특수문자조정(&gt; -> >), 정규표현식을 이용한 한글추출 )
item = items[97]
title = item.get('title').replace('<b>', '').replace('</b>', '')
link = item['link']
description = item.get('description').replace('<b>', '').replace('</b>', '')
# html 특수 문자 처리
description = unescape(description)
# 정규표현식 : 알파벳, 숫자, 한글만 남기고 나머지는 제거
description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
description = re.sub('\s+', ' ', description)
print(title, link, description)
# Out:
# 경주 여행지 추천 https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=261370795&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8  2 부산을 벗어난 경주 여행지 알려주세요 3 당일치기로 경주 여행코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행

# %%
def get_search_element_return(query, start):
    headers = {
        'X-Naver-Client-Id':client_id,
        'X-Naver-Client-Secret':client_secret
    }
    # url = f'https://openapi.naver.com/v1/search/kin?query={query}&display=100&start={start}'
    # response = requests.get(url, headers=headers)
    url = 'https://openapi.naver.com/v1/search/kin'
    params = {'query':query, 'display':100, 'start':start}
    response = requests.get(url, params=params, headers=headers)
    # print(response.text[:500])
    # items = json.loads(response.text)['items']
    items = response.json()['items']
    result = []# 검색한 정보를 append할 리스트
    for i, item in enumerate(items):
        title = item.get('title').replace('<b>', ' ').replace('</b>', ' ')
        link  = item.get('link')
        description = item.get('description').replace('<b>', ' ').replace('</b>', ' ')
        # 특수문자처리
        description = unescape(description)
        # 영문자, 숫자, 한글을 제외한 문자 제거
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        description = re.sub('\s+', ' ', description)
        result.append({
            'query':query,
            'no':(start-1)*100 + i+1,
            'title':title,
            'link':link,
            'description':description,
            'total_text':title + ' ' +description
        })
    return result

# %%
get_search_element_return("경주 여행", 1)
# Out:
# [{'query': '경주 여행',
#   'no': 1,
#   'title': 'APEC 기간  경주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=489795008&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': 'APEC 기간 경주여행 어떻게 생각하시나요 APEC 기간에 경주여행 은 좋은 방법이에요 역사와 문화가 가득한 도시에서 특별한 경험을 할 수 있을 거에요 즐거운 여행 되세요 ',
#   'total_text': 'APEC 기간  경주여행  APEC 기간 경주여행 어떻게 생각하시나요 APEC 기간에 경주여행 은 좋은 방법이에요 역사와 문화가 가득한 도시에서 특별한 경험을 할 수 있을 거에요 즐거운 여행 되세요 '},
#  {'query': '경주 여행',
#   'no': 2,
#   'title': ' 경주 여행  강수량 45% 비 오는거겠죠 ?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=488183062&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '다음주 27일 수요일에 경주 여행 가는데 날씨를 찾아보니 45퍼나 되던데 연달아 비 소식도 잡혀있고 비 오는거 비 오는 날의 운치를 즐길 수 있는 코스를 미리 생각해두시면 좋을 것 같습니다 즐거운 경주 여행 되시길 바랍니다 ',
#   'total_text': ' 경주 여행  강수량 45% 비 오는거겠죠 ? 다음주 27일 수요일에 경주 여행 가는데 날씨를 찾아보니 45퍼나 되던데 연달아 비 소식도 잡혀있고 비 오는거 비 오는 날의 운치를 즐길 수 있는 코스를 미리 생각해두시면 좋을 것 같습니다 즐거운 경주 여행 되시길 바랍니다 '},
#  {'query': '경주 여행',
#   'no': 3,
#   'title': '6~7월  경주 여행 에서 꼭 가봐야 할 명소는?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90105&docId=486500596&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '

#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=480200932&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 가고싶은데 맛집 추천 부탁드려뇨 1 한정식 전통 한식 교동법주 한정식 특징 경주 전통 음식을 품격 있게 경주 여행 중에 황리단길 대릉원 교촌마을 근처는 맛집이 몰려 있는 지역이니 동선에 따라 골라 가보세요 맛있는 ',
#   'total_text': ' 경주 여행  맛집  경주 여행 가고싶은데 맛집 추천 부탁드려뇨 1 한정식 전통 한식 교동법주 한정식 특징 경주 전통 음식을 품격 있게 경주 여행 중에 황리단길 대릉원 교촌마을 근처는 맛집이 몰려 있는 지역이니 동선에 따라 골라 가보세요 맛있는 '},
#  {'query': '경주 여행',
#   'no': 9,
#   'title': ' 경주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81207&docId=489997237&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '경주역에서 황리단길 버스타고 갈건데 많이멀어요 배차시간이나 몇분걸리는지 몇번타는지 알려주세요 택시는 관광지라 할증붙어서 요금 많이나온다고 하던데 맞나요 관광지라 그런 것이 아니라 경주시의 택시 요금 체계가 ',
#   'total_text': ' 경주 여행  경주역에서 황리단길 버스타고 갈건데 많이멀어요 배차시간이나 몇분걸리는지 몇번타는지 알려주세요 택시는 관광지라 할증붙어서 요금 많이나온다고 하던데 맞나요 관광지라 그런 것이 아니라 경주시의 택시 요금 체계가 '},
#  {'query': '경주 여행',
#   'no': 10,
#   'title': ' 경주 여행  중 꼭 가봐야 할 맛집 리스트는 무엇인가요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80208&docId=486315579&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 을 계획 중이며 필수 방문 맛집과 핫플레이스에 대해 알고 싶습니다 현지인들이 추천하는 숨은 맛집이나 경주 여행 추천 리스트 여기 꼭 가봐야 할 맛집과 핫플레이스를 정리해봤어요 1 맛집 교동 맛집 거리 경주의 ',
#   'total_text': ' 경주 여행  중 꼭 가봐야 할 맛집 리스트는 무엇인가요?  경주 여행 을 계획 중이며 필수 방문 맛집과 핫플레이스에 대해 알고 싶습니다 현지인들이 추천하는 숨은 맛집이나 경주 여행 추천 리스트 여기 꼭 가봐야 할 맛집과 핫플레이스를 정리해봤어요 1 맛집 교동 맛집 거리 경주의 '},
#  {'query': '경주 여행',
#   'no': 11,
#   'title': ' 경주여행  30만원',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=482950385&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 2박3일 남자친구랑 가는데 숙소랑 ktx비는 다 냈고 제 개인적으로 30만원이면 부족할까요 30만원으로 경주 여행 을 계획하고 계신다면 예산이 어떻게 집행되느냐에 따라 충분할 수도 부족할 수도 있습니다 ',
#   'total_text': ' 경주여행  30만원  경주 여행 2박3일 남자친구랑 가는데 숙소랑 ktx비는 다 냈고 제 개인적으로 30만원이면 부족할까요 30만원으로 경주 여행 을 계획하고 계신다면 예산이 어떻게 집행되느냐에 따라 충분할 수도 부족할 수도 있습니다 '},
#  {'query': '경주 여행',
#   'no': 12,
#   'title': '[내공100]  경주여행  꼭 가야하는 곳!!!!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12110212&docId=203240749&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 2박3일 경주여행 계획하고 있는 사람입니다 가족여행이구요 이 외에 경주여행 꼭 가야하는 곳이나 여행지 추천해주세요 예 무열왕릉 등 이제 완벽한 경주 여행 코스가 됐네요 추가로 궁금한 점 있으시면 언제든 ',
#   'total_text': '[내공100]  경주여행  꼭 가야하는 곳!!!!! 안녕하세요 2박3일 경주여행 계획하고 있는 사람입니다 가족여행이구요 이 외에 경주여행 꼭 가야하는 곳이나 여행지 추천해주세요 예 무열왕릉 등 이제 완벽한 경주 여행 코스가 됐네요 추가로 궁금한 점 있으시면 언제든 '},
#  {'query': '경주 여행',
#   'no': 13,
#   'title': ' 경주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId
qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 을 계획 중인데 대릉원 외에도 6월과 7월에 방문하기 좋은 명소들이 많다고 들었습니다 첨성대 동궁과 월지 황리단길 등 다양한 곳 중에서 특히 추천할 만한 장소와 그곳에서 즐길 수 있는 특별한 활동이 있다면 알고 ',
#   'total_text': '6-7월  경주 여행  대릉원 외 꼭 방문해야 할 명소는?  경주 여행 을 계획 중인데 대릉원 외에도 6월과 7월에 방문하기 좋은 명소들이 많다고 들었습니다 첨성대 동궁과 월지 황리단길 등 다양한 곳 중에서 특히 추천할 만한 장소와 그곳에서 즐길 수 있는 특별한 활동이 있다면 알고 '},
#  {'query': '경주 여행',
#   'no': 18,
#   'title': ' 경주 여행  시 황리단길 주차 정보와 주변 관광지 연계... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81208&docId=489487593&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 중 황리단길을 방문할 계획인데 주차가 걱정입니다 황리단길 주변의 주차장 정보와 이용 팁을 알고 황리단길 근처에 공영 주차장이 있어요 주차 후 도보로 불국사 석굴암 등 관광지 방문 가능해용 즐거운 경주 여행 되세요 ',
#   'total_text': ' 경주 여행  시 황리단길 주차 정보와 주변 관광지 연계...   경주 여행 중 황리단길을 방문할 계획인데 주차가 걱정입니다 황리단길 주변의 주차장 정보와 이용 팁을 알고 황리단길 근처에 공영 주차장이 있어요 주차 후 도보로 불국사 석굴암 등 관광지 방문 가능해용 즐거운 경주 여행 되세요 '},
#  {'query': '경주 여행',
#   'no': 19,
#   'title': ' 경주여행 지 2박3일 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=480019503&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '이번에 남자친구 전역 직전으로 경주 여행 을 가기로 했는데요 둘다 황리단길 외엔 아는게 없어서요 차가 있어서 경주여행 을 계획하고 계시는군요 별다섯개 경주 2박3일 여행코스를 공유하니 내용 참고하시면 좋을 것같습니다 ',
#   'total_text': ' 경주여행 지 2박3일 추천 이번에 남자친구 전역 직전으로 경주 여행 을 가기로 했는데요 둘다 황리단길 외엔 아는게 없어서요 차가 있어서 경주여행 을 계획하고 계시는군요 별다섯개 경주 2박3일 여행코스를 공유하니 내용 참고하시면 좋을 것같습니다 '},
#  {'query': '경주 여행',
#   'no': 20,
#   'title': ' 경주 여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=489283598&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 야경이나 놀거리좀 알려주세여 경주 여행 코스 추천할게요 불국사와 석굴암은 꼭 가보고 경주 월드에서 놀이기구도 즐겨요 저녁엔 동궁과 월지에서 야경을 감상하는 것도 좋겠네요 맛집은 한옥마을 근처의 찰보리밥을 ',
#   'total_text': ' 경주 여행 코스  야경이나 놀거리좀 알려주세여 경주 여행 코스 추천할게요 불국사와 석굴암은 꼭 가보고 경주 월드에서 놀이기구도 즐겨요 저녁엔 동궁과 월지에서 야경을 감상하는 것도 좋겠네요 맛집은 한옥마을 근처의 찰보리밥을 '},
#  {'query': '경주 여행',
#   'no': 21,
#   'title': '2박3일  경주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=473589663&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '10월 2박3일 경주 여행 코스 및 식당 추천부탁드립니다 1인여행 숙소는 경주 여행 가실 때 방문하시기 좋은 뷰 예쁜 카페입니다포토존도 많고 다양한 작품도 함께 감상할 수 있는 카페라서 경주 여행 에 참고해 수면 좋을거 같아요',
#   'total_text': '2박3일  경주 여행  10월 2박3일 경주 여행 코스 및 식당 추천부탁드립니다 1인여행 숙소는 경주 여행 가실 때 방문하시기 좋은 뷰 예쁜 카페입니다포토존도 많고 다양한 작품도 함께 감상할 수 있는 카페라서 경주 여행 에 참고해 수면 좋을거 같아요'},
#  {'query': '경주 여행',
#   'no': 22,
#   'title': '1박2일  경주 여행  일정 짜주세요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=484345851&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '1박2일 경주 여행 일정 짜주세요 경주 여행 1박2일 추천 코스 입니다 https info idea114 co kr 70',
#   'total_text': '1박2일  경주 여행  일정 짜주세요 1박2일 경주 여행 일정 짜주세요 경주 여행 1박2일 추천 코스 입니다 https info idea114 co kr 70'},
#  {'query': '경주 여행',
#   'no': 23,
#   'title': ' 경주여행  코스 동선 어떻게 짜야될까요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90101&docId=448411905&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 자차 이용해서 1박2일로 경주 여행 을 가려고 합니다 경주여행 코스 동선 어떻게 짜야될까요 이 문제에 대한 해결책을 제시해 드리도록 하겠습니다 Step 1 경주여행 이처럼 경주여행 코스 동선을 메인으로 잡은 장소와 그와 ',
#   'total_text': ' 경주여행  코스 동선 어떻게 짜야될까요?  자차 이용해서 1박2일로 경주 여행 을 가려고 합니다 경주여행 코스 동선 어떻게 짜야될까요 이 문제에 대한 해결책을 제시해 드리도록 하겠습니다 Step 1 경주여행 이처럼 경주여행 코스 동선을 메인으로 잡은 장소와 그와 '},
#  {'query': '경주 여행',
#   'no': 24,
#   'title': '엄마와 경주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90101&docId=442736977&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '엄마와 경주여행 평일에 대중교통타고 가려고하는데요 일단불국사가고 도보 대중교통 이용의 경주 여행 코스 의견 드려 볼께요 먼저 평일 어머니와 어머니와 행복한 경주 여행 되세요 경주 주요 관광지의 교통편 도보 포함 ',
#   'total_text': '엄마와 경주여행  엄마와 경주여행 평일에 대중교통타고 가려고하는데요 일단불국사가고 도보 대중교통 이용의 경주 여행 코스 의견 드려 볼께요 먼저 평일 어머니와 어머니와 행복한 경주 여행 되세요 경주 주요 관광지의 교통편 도보 포함 '},
#  {'query': '경주 여행',
#   'no': 25,
#   'title': '초등학생 경주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=455869243&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '전남에서 2박3일로 초등학생데리고 경주여행 을 가져고하는데요 아 코스짜기가 쉽지않네요 숙소는 질문하신 경주여행 지 관련 답변 드리도록 하겠습니다 2박3일간 다녀올만한 곳으로 경주여행 지를 찾고 계시나 봅니다 경주에 ',
#   'total_text': '초등학생 경주여행  전남에서 2박3일로 초등학생데리고 경주여행 을 가져고하는데요 아 코스짜기가 쉽지않네요 숙소는 질문하신 경주여행 지 관련 답변 드리도록 하겠습니다 2박3일간 다녀올만한 곳으로 경주여행 지를 찾고 계시나 봅니다 경주에 '},
#  {'query': '경주 여행',
#   'no': 26,
#   'title': ' 경주 여행  질문',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=469077239&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 경주여행 을 가본 적이 없는데 이번에 가보려고 하거든요 1일 정도 돌아다닐 거 같은데 버스와 렌트카 반갑습니다 살아 있는 문화 유산의 도시 경주 여행 을 1인 당일 로 준비중이시네요 경주 방문이 처음이시라면 ',
#   'total_text': ' 경주 여행  질문 안녕하세요 경주여행 을 가본 적이 없는데 이번에 가보려고 하거든요 1일 정도 돌아다닐 거 같은데 버스와 렌트카 반갑습니다 살아 있는 문화 유산의 도시 경주 여행 을 1인 당일 로 준비중이시네요 경주 방문이 처음이시라면 '},
#  {'query': '경주 여행',
#   'no': 27,
#   'title': '가을때 가기 좋은  경주 여행 지가 어디인가요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId
qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '2주후에 여자친구와 같이 경주여행 을 하기로 했어요 차를 가지고 갈 예정인데요 경주여행 어떤식으로 코스를 잡고 가는것이 좋을까요 그리고 경주여행 코스 지도를 알아보고 외 경주여행 하면서 갈만한 곳 몇군데도 알려주세요 경주 ',
#   'total_text': ' 경주여행  코스(지도),숙소 2주후에 여자친구와 같이 경주여행 을 하기로 했어요 차를 가지고 갈 예정인데요 경주여행 어떤식으로 코스를 잡고 가는것이 좋을까요 그리고 경주여행 코스 지도를 알아보고 외 경주여행 하면서 갈만한 곳 몇군데도 알려주세요 경주 '},
#  {'query': '경주 여행',
#   'no': 32,
#   'title': ' 경주여행 3박4일 갈려고하는데 24만원 괜찮을까요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=460586156&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '애인이랑 3박4일 경주여행 갈려고하는데 돈을 제가 다쓸려고 맘먹었는데 24만원이면 충분할까요 경주여행 3박4일 갈려고하는데 245000원 괜찮을까 애인이랑 3박4일 경주여행 갈려고하는데 돈을 제가 다쓸려고 맘먹었는데 24만원이면 ',
#   'total_text': ' 경주여행 3박4일 갈려고하는데 24만원 괜찮을까요 애인이랑 3박4일 경주여행 갈려고하는데 돈을 제가 다쓸려고 맘먹었는데 24만원이면 충분할까요 경주여행 3박4일 갈려고하는데 245000원 괜찮을까 애인이랑 3박4일 경주여행 갈려고하는데 돈을 제가 다쓸려고 맘먹었는데 24만원이면 '},
#  {'query': '경주 여행',
#   'no': 33,
#   'title': '2월 1~2일  경주여행  날씨',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=481101676&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '2월 1 2일로 경주여행 가는데 현재 날씨가 어떤가요 눈 쌓였나요 시외버스타고 가는데 빙판길일까봐 불안해요 경주는 눈 그렇게 많이오지 않고 날씨도 많이 춥지는 않아요 주말에 춥다고는 해도 그때예보를 보는게 좋겠죠',
#   'total_text': '2월 1~2일  경주여행  날씨 2월 1 2일로 경주여행 가는데 현재 날씨가 어떤가요 눈 쌓였나요 시외버스타고 가는데 빙판길일까봐 불안해요 경주는 눈 그렇게 많이오지 않고 날씨도 많이 춥지는 않아요 주말에 춥다고는 해도 그때예보를 보는게 좋겠죠'},
#  {'query': '경주 여행',
#   'no': 34,
#   'title': ' 경주여행  실내관광',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=450211953&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 가는데 비가 많이 오더라고요 실내로 가는 곳 추천 좀 해주세요 검색을 기반 삼아 경주에서 비가 오는 실제 방문하시는 날씨와 여행 일정에 따라 운영시간을 확인해 보시고 즐거운 경주 여행 되시길 바랍니다 채택해 ',
#   'total_text': ' 경주여행  실내관광  경주여행 가는데 비가 많이 오더라고요 실내로 가는 곳 추천 좀 해주세요 검색을 기반 삼아 경주에서 비가 오는 실제 방문하시는 날씨와 여행 일정에 따라 운영시간을 확인해 보시고 즐거운 경주 여행 되시길 바랍니다 채택해 '},
#  {'query': '경주 여행',
#   'no': 35,
#   'title': '3월 1일  경주 여행  코스 (당일치기)',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=413559176&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '학생 4명이고 3 1 경주 여행 코스 좀 알려주세요 첨성대 근처 한복나드리에서 질문하신 경주 여행 일정 관련 답변 드리도록 하겠습니다 황리단길과 맞춤형 경주 여행 일정을 준비했어요 아래 첨부된 일정을 참고해보시고 여행에 ',
#   'total_text': '3월 1일  경주 여행  코스 (당일치기) 학생 4명이고 3 1 경주 여행 코스 좀 알려주세요 첨성대 근처 한복나드리에서 질문하신 경주 여행 일정 관련 답변 드리도록 하겠습니다 황리단길과 맞춤형 경주 여행 일정을 준비했어요 아래 첨부된 일정을 참고해보시고 여행에 '},
#  {'query': '경주 여행',
#   'no': 36,
#   'title': '혼자 떠나는  경주 여행 , 안전하고 즐거운 코스는?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId

#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=465334623&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '한시간 뒤면 경주 도착하는데 경주여행 가서 여기는 꼭가봐야한다하는 식당이 경주 여행 에서 특별한 대접을 받을 수 있는 식당을 추천해드리겠습니다 위 두 식당 중 하나를 선택하시면 경주 여행 에서 특별한 대접을 받을 수 있을 ',
#   'total_text': ' 경주 여행  식당 추천 부탁드립니다 한시간 뒤면 경주 도착하는데 경주여행 가서 여기는 꼭가봐야한다하는 식당이 경주 여행 에서 특별한 대접을 받을 수 있는 식당을 추천해드리겠습니다 위 두 식당 중 하나를 선택하시면 경주 여행 에서 특별한 대접을 받을 수 있을 '},
#  {'query': '경주 여행',
#   'no': 42,
#   'title': ' 경주 여행 일정 도와주세요!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=407408414&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 그냥 최소한의 움직임으로 이틀동안 다녀올 수 있는 경주 여행 코스좀 알려주세요 예쁜 카페도 추천 질문하신 경주 여행 일정 관련 답변 드리도록 하겠습니다 질문자님께서 원하신대로 최대한 여유로운 경주 여행 일정을 준비해 ',
#   'total_text': ' 경주 여행 일정 도와주세요!!  그냥 최소한의 움직임으로 이틀동안 다녀올 수 있는 경주 여행 코스좀 알려주세요 예쁜 카페도 추천 질문하신 경주 여행 일정 관련 답변 드리도록 하겠습니다 질문자님께서 원하신대로 최대한 여유로운 경주 여행 일정을 준비해 '},
#  {'query': '경주 여행',
#   'no': 43,
#   'title': '뚜벅이  경주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=443286794&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '다음주 평일에 화 수 중 경주여행 가려고 했는데 시기상 뷰가 별로 일 거 같아서 고민입니다 혼자 뚜벅이 꽃피고 봄바람 살랑살랑 부는 4월달 경주여행 오푸스에서 즐겨보세요 전객실 개별바베큐장으로 ',
#   'total_text': '뚜벅이  경주여행  다음주 평일에 화 수 중 경주여행 가려고 했는데 시기상 뷰가 별로 일 거 같아서 고민입니다 혼자 뚜벅이 꽃피고 봄바람 살랑살랑 부는 4월달 경주여행 오푸스에서 즐겨보세요 전객실 개별바베큐장으로 '},
#  {'query': '경주 여행',
#   'no': 44,
#   'title': ' 경주 여행  감성 독채 자쿠지 숙소 추천 부탁드립니다.',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=439595095&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '3월 마지막 주에 경주 여행 을 계획하고 있습니다 어른5명 4세 아이 가능한 독채 자쿠지 숙소 괜찮은 곳 있으면 추천 휴식을 취하고자 하는 분들께 최적의 선택입니다 즐거운 경주 여행 되시길 바랍니다 http itta stay kr html index html',
#   'total_text': ' 경주 여행  감성 독채 자쿠지 숙소 추천 부탁드립니다. 3월 마지막 주에 경주 여행 을 계획하고 있습니다 어른5명 4세 아이 가능한 독채 자쿠지 숙소 괜찮은 곳 있으면 추천 휴식을 취하고자 하는 분들께 최적의 선택입니다 즐거운 경주 여행 되시길 바랍니다 http itta stay kr html index html'},
#  {'query': '경주 여행',
#   'no': 45,
#   'title': ' 경주여행 가려는데 추천좀요!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=407810074&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description':

#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=416117973&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '저희 가족과 저희 부모님을 모시고 경주여행 을 2박3일 질문하신 경주 여행 코스 관련 답변드리겠습니다 가족 분들과 함께 경주 여행 을 계획하고 계시는군요 가족 3일 경주 여행 일정을 준비했어요 아래 첨부된 일정을 참고해 ',
#   'total_text': ' 경주 여행  2박3일 코스 조언부탁드립니다. 저희 가족과 저희 부모님을 모시고 경주여행 을 2박3일 질문하신 경주 여행 코스 관련 답변드리겠습니다 가족 분들과 함께 경주 여행 을 계획하고 계시는군요 가족 3일 경주 여행 일정을 준비했어요 아래 첨부된 일정을 참고해 '},
#  {'query': '경주 여행',
#   'no': 61,
#   'title': '추석에  경주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=474844021&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '추석에 경주 여행 가는거 어떻게 생각하시나요 서울에서 버스를 타고 갈 경우 버스가 버스전용 차선에서 운행하나요 질문하신 추석 경주여행 관련 답변 드리도록 하겠습니다 첨성대 석굴암 불국사 등 유적지는 연중무휴로 ',
#   'total_text': '추석에  경주 여행  추석에 경주 여행 가는거 어떻게 생각하시나요 서울에서 버스를 타고 갈 경우 버스가 버스전용 차선에서 운행하나요 질문하신 추석 경주여행 관련 답변 드리도록 하겠습니다 첨성대 석굴암 불국사 등 유적지는 연중무휴로 '},
#  {'query': '경주 여행',
#   'no': 62,
#   'title': '[추천해주세요]  경주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80204&docId=437683257&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 추천해주세요 경주여행 안녕하세요 무계획 이 루트로 이용시 실패없는 경주여행 소개해드릴까 합니다 한번 보시고 마음에 드신다면 채택 부탁드립니다 ',
#   'total_text': '[추천해주세요]  경주여행   추천해주세요 경주여행 안녕하세요 무계획 이 루트로 이용시 실패없는 경주여행 소개해드릴까 합니다 한번 보시고 마음에 드신다면 채택 부탁드립니다 '},
#  {'query': '경주 여행',
#   'no': 63,
#   'title': ' 경주여행  추천부탁드려요~^^',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=413669755&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 을 다녀오고싶은데 기본적으로 가볼만한곳들 말고 특별히 가보면 좋을곳이 있을까요 맛집이나 문의주신 경주 가볼만한곳 추천드릴게요 즐거운 경주여행 되셨으면 좋겠어요 경북 경주 가볼만한곳 1 ',
#   'total_text': ' 경주여행  추천부탁드려요~^^  경주여행 을 다녀오고싶은데 기본적으로 가볼만한곳들 말고 특별히 가보면 좋을곳이 있을까요 맛집이나 문의주신 경주 가볼만한곳 추천드릴게요 즐거운 경주여행 되셨으면 좋겠어요 경북 경주 가볼만한곳 1 '},
#  {'query': '경주 여행',
#   'no': 64,
#   'title': '2박3일  경주여행  코스 추천이요!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=226543245&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 요번에는 색다른 주제로 경주 여행 을 하고 싶어요 2박3일 경주여행 코스 추천입니다 안녕하세요 2코스 경주 남산 정복하기 경주 여행 코스 중에서 많은 4코스 불국사와 석굴암 관람하기 경주여행 의 랜드마크죠 ',
#   'total_text': '2박3일  경주여행  코스 추천이요!  요번에는 색다른 주제로 경주 여행 을 하고 싶어요 2박3일 경주여행 코스 추천입니다 안녕하세요 2코스 경주 남산 정복하기 경주 여행 코스 중에서 많은 4코스 불국사와 석굴암 관람하기 경주여행 의 랜드마크죠 '},
#  {'query': '경주 여행',
#   'no': 65,
#   'title': ' 경주여행 시기',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId
qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 을 가려고 합니다 우선 숙소는 터미널 주요 관광지를 도보 5 10분 경주 여행 관광지 추천해드리겠습니다 말씀하신 터미널 에서 주요 관광지는 경주 여행 은 황리단길에서 시작한다고 보시면 됩니다 황리단길을 시작으로 ',
#   'total_text': ' 경주 여행  렌터카 문의  경주여행 을 가려고 합니다 우선 숙소는 터미널 주요 관광지를 도보 5 10분 경주 여행 관광지 추천해드리겠습니다 말씀하신 터미널 에서 주요 관광지는 경주 여행 은 황리단길에서 시작한다고 보시면 됩니다 황리단길을 시작으로 '},
#  {'query': '경주 여행',
#   'no': 70,
#   'title': ' 경주여행  렌트',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=407610181&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '렌트해서 경주여행 할려하는데 경주도 부산처럼 운전하는거 많이 빡센가여 부산에 살고 있다보니 종종 경주여행 을 가는데 일단 차가 많이 몰리는 곳은 황리단길 첨성대 인근 대릉원인근 경주시내 정도 입니다 여기 외에는 운전하는데 ',
#   'total_text': ' 경주여행  렌트 렌트해서 경주여행 할려하는데 경주도 부산처럼 운전하는거 많이 빡센가여 부산에 살고 있다보니 종종 경주여행 을 가는데 일단 차가 많이 몰리는 곳은 황리단길 첨성대 인근 대릉원인근 경주시내 정도 입니다 여기 외에는 운전하는데 '},
#  {'query': '경주 여행',
#   'no': 71,
#   'title': '1박2일로  경주여행 을 갑니다',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121102&docId=426744108&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '1박2일로 경주여행 을 갑니다 천군동에 위치한 풀빌라 3시 입실인데 경주 12시 도착예정이라서 그동안 안녕하세요 무계획없이 이 루트로 가면 실패가 없는 경주여행 소개해볼까 합니다 한번 보시고 마음에 드신다면 ',
#   'total_text': '1박2일로  경주여행 을 갑니다 1박2일로 경주여행 을 갑니다 천군동에 위치한 풀빌라 3시 입실인데 경주 12시 도착예정이라서 그동안 안녕하세요 무계획없이 이 루트로 가면 실패가 없는 경주여행 소개해볼까 합니다 한번 보시고 마음에 드신다면 '},
#  {'query': '경주 여행',
#   'no': 72,
#   'title': ' 경주 여행 에 빠질 수 없는 빵집?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=329388645&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주 여행 에 빠질 수 없는 빵집 알려주세요 주말에 남편과 경주 여행 갑니다 제가 빵을 너무 좋아하는데 경주 여행 에서만 먹을 수 있는 빵집 어딘가요 경주 여행 하기 좋은 계절입니다 저도 늘 이맘때 아이들과 경주에 가거든요 ',
#   'total_text': ' 경주 여행 에 빠질 수 없는 빵집?  경주 여행 에 빠질 수 없는 빵집 알려주세요 주말에 남편과 경주 여행 갑니다 제가 빵을 너무 좋아하는데 경주 여행 에서만 먹을 수 있는 빵집 어딘가요 경주 여행 하기 좋은 계절입니다 저도 늘 이맘때 아이들과 경주에 가거든요 '},
#  {'query': '경주 여행',
#   'no': 73,
#   'title': '이번에  경주여행  가는데요 질문좀요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=489713561&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 차도 막히고 못들어가는데가 많을 것 같은데 경주 여행 계획 중이시군요 에이팩 행사로 차가 막힐 거에요 그래서 여행이 불편할 수 있어요 다른 일정으로 조정해보는 게 좋을 것 같아요 즐거운 여행 되시길 바랄게요 ',
#   'total_text': '이번에  경주여행  가는데요 질문좀요  차도 막히고 못들어가는데가 많을 것 같은데 경주 여행 계획 중이시군요 에이팩 행사로 차가 막힐 거에요 그래서 여행이 불편할 수 있어요 다른 일정으로 조정해보는 게 좋을 것 같아요 즐거운 여행 되시길 바랄게요 '},
#  {'query': '경주 여행',
#   'no': 74,
#   'title': ' 경주 여행 !! 황리단길 맛집추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId
qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '여자친구랑 경주 여행 을 가려고 하는데 뚜벅이로 돌아다닐 코스 좀 추천해주세요 경주월드는 제외하고요 그 여자친구와 가볼만한 경주여행 코스 추천드릴게요 좋은하루 되세요 경주 가볼만한곳 1 경주 ',
#   'total_text': '뚜벅이  경주 여행  1박 코스 추천 좀요 여자친구랑 경주 여행 을 가려고 하는데 뚜벅이로 돌아다닐 코스 좀 추천해주세요 경주월드는 제외하고요 그 여자친구와 가볼만한 경주여행 코스 추천드릴게요 좋은하루 되세요 경주 가볼만한곳 1 경주 '},
#  {'query': '경주 여행',
#   'no': 79,
#   'title': ' 경주여행  지금',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121102&docId=365192852&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 3가지만 답해주세요 1 지금 경주여행 가면 많이 더울까요 2 쪄죽을정도로 못돌아다니나요 3 고속버스타고 1 지금 경주여행 가면 많이 더울까요 가장 더운 시기입니다 낮에 30도가 넘고 34도까지 갈수도 있습니다 2 ',
#   'total_text': ' 경주여행  지금  경주여행 3가지만 답해주세요 1 지금 경주여행 가면 많이 더울까요 2 쪄죽을정도로 못돌아다니나요 3 고속버스타고 1 지금 경주여행 가면 많이 더울까요 가장 더운 시기입니다 낮에 30도가 넘고 34도까지 갈수도 있습니다 2 '},
#  {'query': '경주 여행',
#   'no': 80,
#   'title': '1박2일 어르신들과함께  경주여행 ~숙소와... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=448650337&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '1박2일 어르신들 경주여행 추천 해주세요 인원20 25명 숙소는 식사가 함께 경주여행 추천 안녕하세요 경주여행 에 관심이 있으신 것 같아서 저희가 함께하는 경주여행 에서는 역사와 문화를 경험할 수 있는 명소를 추천합니다 ',
#   'total_text': '1박2일 어르신들과함께  경주여행 ~숙소와...  1박2일 어르신들 경주여행 추천 해주세요 인원20 25명 숙소는 식사가 함께 경주여행 추천 안녕하세요 경주여행 에 관심이 있으신 것 같아서 저희가 함께하는 경주여행 에서는 역사와 문화를 경험할 수 있는 명소를 추천합니다 '},
#  {'query': '경주 여행',
#   'no': 81,
#   'title': ' 경주여행 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=399825700&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '50대부부10월여행 경주여행 1박2일코스 밤야경과숙소및먹거리추천부탁합니다 경주 여행 을 계획 중이시군요 그럼 경주에서 가볼 만한 곳들 추천해드리겠습니다 첨성대 동궁과 월지 대릉원 ',
#   'total_text': ' 경주여행 추천 50대부부10월여행 경주여행 1박2일코스 밤야경과숙소및먹거리추천부탁합니다 경주 여행 을 계획 중이시군요 그럼 경주에서 가볼 만한 곳들 추천해드리겠습니다 첨성대 동궁과 월지 대릉원 '},
#  {'query': '경주 여행',
#   'no': 82,
#   'title': ' 경주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=477081199&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '2월에 2박3일로 경주 여행 가려고 하는데 펜션이나 호텔 예약은 몇달전부터 하는 게 좋을까요 1달전이 제일 좋습니다만 가는 날짜들이 성수기라면 2달전에 하는게 좋겠죠 ',
#   'total_text': ' 경주 여행  2월에 2박3일로 경주 여행 가려고 하는데 펜션이나 호텔 예약은 몇달전부터 하는 게 좋을까요 1달전이 제일 좋습니다만 가는 날짜들이 성수기라면 2달전에 하는게 좋겠죠 '},
#  {'query': '경주 여행',
#   'no': 83,
#   'title': '1박2일 초보운전  경주여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=248854588&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 1박2일로 경주여행 코스좀 짜주세요 아무래도 가는데는 어려움이 없을것 4월 1 2일에 경주여행 하기에 좋은 날일 것 같아요 벚꽃들이 서서히 개화를 참고로 쭈니아빠 블로그를 방문하시면 경주여행 카테고리가 있습니다 ',
#   'total_text': '1박2일 초보운전  경주여행 코스  1박2일로 경주여행 코스좀 짜주세요 아무래도 가는데는 어려움이 없을것 4월 1 2일에 경주여행 하기에 좋은 날일 것 같아요 벚꽃들이 서서히 개화를 참고로 쭈니아빠 블로그를 방문하시면 경주여행 카테고리가 있습니다 '},
#  {'query': '경주 여행',
#   'no': 84,
#   'title': ' 경주여행  1박2일 알찬코스로 추천해주세요 ^^',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90105&docId=434332784&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 1박2일 알찬코스로 추천해주세요 1박이라 짧지만 질문하신 경주여행 관련 답변 드리도록 하겠습니다 1박2일 경주여행 을 다녀오실 예정이시군요 가볼만한 곳들 좋으니 경주 여행 하시는데 참고하시기 바랍니다 도움이 ',
#   'total_text': ' 경주여행  1박2일 알찬코스로 추천해주세요 ^^  경주여행 1박2일 알찬코스로 추천해주세요 1박이라 짧지만 질문하신 경주여행 관련 답변 드리도록 하겠습니다 1박2일 경주여행 을 다녀오실 예정이시군요 가볼만한 곳들 좋으니 경주 여행 하시는데 참고하시기 바랍니다 도움이 '},
#  {'query': '경주 여행',
#   'no': 85,
#   'title': '아들과(초4년)  경주여행  일정!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=230463403&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 아들과 경주여행 을 가려합니다 선배님들의 조언을 경주여행 코스 추천드립니다 안녕하세요 여행전문블로거 초등학교 4학년 아들과 함께 가는 경주여행 이라면 역사와 하루 코스 경주 남산 정복하기 경주 여행 코스 중에서 ',
#   'total_text': '아들과(초4년)  경주여행  일정!  아들과 경주여행 을 가려합니다 선배님들의 조언을 경주여행 코스 추천드립니다 안녕하세요 여행전문블로거 초등학교 4학년 아들과 함께 가는 경주여행 이라면 역사와 하루 코스 경주 남산 정복하기 경주 여행 코스 중에서 '},
#  {'query': '경주 여행',
#   'no': 86,
#   'title': ' 경주 여행 을 가려고 함니다,,!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=13&dirId=130102&docId=38195921&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '저희 가족이 2박 3일로 경주 여행 을 가려고 합니다 가족은 4인가족 3학년 5학년 이구요 경주에 있는 문화재를 보고 작년 여름방학 때 저도 경주여행 한 번 했었죠 저는 2박3일로 갔다온게 아니라 당일로 갔다왔습니다 성심껏 답변 ',
#   'total_text': ' 경주 여행 을 가려고 함니다,,! 저희 가족이 2박 3일로 경주 여행 을 가려고 합니다 가족은 4인가족 3학년 5학년 이구요 경주에 있는 문화재를 보고 작년 여름방학 때 저도 경주여행 한 번 했었죠 저는 2박3일로 갔다온게 아니라 당일로 갔다왔습니다 성심껏 답변 '},
#  {'query': '경주 여행',
#   'no': 87,
#   'title': ' 경주여행  갈만한곳 알려주세요!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=228946682&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 을 가려고 합니다 2박3일 경주를 관광하며 옛 문화와 정서를 배워보고 체험하고자 경주여행 계획을 세우고 있는데요 1일차 2일차 3일차 어떤식으로 경주여행 계획을 세워야할지 궁금합니다 가족들과 함께하는 경주여행 ',
#   'total_text': ' 경주여행  갈만한곳 알려주세요!!  경주여행 을 가려고 합니다 2박3일 경주를 관광하며 옛 문화와 정서를 배워보고 체험하고자 경주여행 계획을 세우고 있는데요 1일차 2일차 3일차 어떤식으로 경주여행 계획을 세워야할지 궁금합니다 가족들과 함께하는 경주여행 '},
#  {'query': '경주 여행',
#   'no': 88,
#   'title': ' 경주여행  질문',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=
qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '여자친구랑 경주여행 갈려고 하는데요 혹시 가볼만한 곳이나 경치 좋은 곳 있을까요 차타구 이동할꺼구요 해주셍 경주 여행 을 계획하고 계시는군요 요즘 경주로 여행 가시는 분들이 정말 많은데요 그만큼 ',
#   'total_text': ' 경주여행 지 여자친구랑 경주여행 갈려고 하는데요 혹시 가볼만한 곳이나 경치 좋은 곳 있을까요 차타구 이동할꺼구요 해주셍 경주 여행 을 계획하고 계시는군요 요즘 경주로 여행 가시는 분들이 정말 많은데요 그만큼 '},
#  {'query': '경주 여행',
#   'no': 98,
#   'title': ' 경주 여행 지 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=261370795&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 2 부산을 벗어난 경주 여행 지 알려주세요 3 당일치기로 경주 여행 코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행 이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행 ',
#   'total_text': ' 경주 여행 지 추천  2 부산을 벗어난 경주 여행 지 알려주세요 3 당일치기로 경주 여행 코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행 이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행 '},
#  {'query': '경주 여행',
#   'no': 99,
#   'title': ' 경주 여행 코스,경비,,,,,,',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=74091594&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '10월말이나 11월초에 경주 여행 가려고합니다 여자친구랑요 질문 경주여행 과 바닷가에서 감포 봉길해변 숙박도 한다면 2박3일은 경주여행 터미날 또는 경주역에서 이동시에는 10번 버스를 이용하면 편리 ',
#   'total_text': ' 경주 여행 코스,경비,,,,,, 10월말이나 11월초에 경주 여행 가려고합니다 여자친구랑요 질문 경주여행 과 바닷가에서 감포 봉길해변 숙박도 한다면 2박3일은 경주여행 터미날 또는 경주역에서 이동시에는 10번 버스를 이용하면 편리 '},
#  {'query': '경주 여행',
#   'no': 100,
#   'title': ' 경주여행  내공有',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=75419492&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 경주여행 일정을 짜야하는데요 불국사 포석정 안압지 첨성대 무열왕릉 성덕대왕릉을 간다면 위치상으로 순서대로 기림사 분황사 부처골 무열왕릉 석굴암 황룡사지 오릉 국립경주박물관 참고하시어 유쾌한 경주여행 하시기를 ',
#   'total_text': ' 경주여행  내공有  경주여행 일정을 짜야하는데요 불국사 포석정 안압지 첨성대 무열왕릉 성덕대왕릉을 간다면 위치상으로 순서대로 기림사 분황사 부처골 무열왕릉 석굴암 황룡사지 오릉 국립경주박물관 참고하시어 유쾌한 경주여행 하시기를 '}]

# %%
import time
result_total = [] # 모든 검색 결과
queries = ['전주 여행', '경주 여행']
max_start = 5
for query in queries:
    for start in range(1, max_start+1):
        print(start, query, '읽는 중')
        result_total.extend(get_search_element_return(query, start))
        time.sleep(0.5)
df = pd.DataFrame(result_total)
df.to_csv('data/naver.csv', index=False)
# Out:
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 5 전주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중
# 5 경주 여행 읽는 중

# %% [markdown]
# # 2. 품사태깅 백업
# - query, no, token, pos

# %%
import pandas as pd
df=pd.read_csv('data/naver.csv')
df.tail(2)
# Out:
#      query   no               title  \
# 998  경주 여행  499   경주 여행 가면 볼거 많겠죠??
# 999  경주 여행  500             경주여행 !!
#
#                                                   link  \
# 998  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 999  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 998  중학생인데 경주 여행 가볼려고 하는데 볼거 많겠죠 경주 가볼만한곳 입니다 불국사 첨...
# 999   경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 할 수 있는곳이나...
#
#                                             total_text
# 998   경주 여행 가면 볼거 많겠죠?? 중학생인데 경주 여행 가볼려고 하는데 볼거 많겠죠...
# 999   경주여행 !!  경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 ...

# %%
df[['query','no', 'total_text']].values
# Out:
# array([['전주 여행', 1,
#         '25년10월5,6,7일  전주여행   전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 '],
#        ['전주 여행', 2,
#         'KTX로 떠나는  전주 여행 , 주요 관광지 도보 이동...   전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 '],
#        ['전주 여행', 3,
#         '아이와  전주여행  7월 중순에 초3아이와 같이 당일치기로 전주여행 다녀올려는데 어딜가야할까요 전주는 처음이라 어디가야할지 식당은 어디가 맛있을지 모르겠어요 안녕하세요 7월 중순에 초3 아이와 전주 당일치기 여행이라면 아이도 즐겁고 부모님도 '],
#        ...,
#        ['경주 여행', 498,
#         '2박 3일  경주여행  이동방법 알려주세요~ 다음주에 친구랑 경주여행 을 계획하고 있습니다 그런데 감사하겠습니다 경주여행 일정과 형편에 맞게 054 743 6001 아래사이트에서 경주여행 후기 몇편만 읽어보면 많은 도움이 될것입니다 좋은 경주여행 다녀 '],
#        ['경주 여행', 499,
#         ' 경주 여행 가면 볼거 많겠죠?? 중학생인데 경주 여행 가볼려고 하는데 볼거 많겠죠 경주 가볼만한곳 입니다 불국사 첨성대 석굴암 대릉원 문무대왕릉 동궁과월지 입니다'],
#        ['경주 여행', 500,
#         ' 경주여행 !!  경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 할 수 있는곳이나 싸게 구매하는 할 수있는곳 그리고 경주여행 온다고 하시니 숙소가 제일 중요하잖아요 그래서 저희 오푸스11 풀빌라펜션을 추천해드리려고 ']],
#       dtype=object)

# %%
df_list=df[['query','no', 'total_text']].values.tolist()
df_list[::500]
# Out:
# [['전주 여행',
#   1,
#   '25년10월5,6,7일  전주여행   전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 '],
#  ['경주 여행',
#   1,
#   'APEC 기간  경주여행  APEC 기간 경주여행 어떻게 생각하시나요 APEC 기간에 경주여행 은 좋은 방법이에요 역사와 문화가 가득한 도시에서 특별한 경험을 할 수 있을 거에요 즐거운 여행 되세요 ']]

# %%
from mecab import MeCab
analyzer = MeCab()
postagged_list = [] # query, no, token, pos 딕셔너리 list
stopwords = {'전주', '경주', '여행'}
for i, row in enumerate(df_list):
    query = row[0]
    no    = row[1]
    text  = row[2]
    tagged_text = analyzer.pos(text)
#     if i%250==0:
#         print("{}의 {}번째 품사태깅결과 : {}개".format(query, no, len(tagged_text)))
    for token, pos in tagged_text:
        if token not in stopwords:
            postagged_list.append({
                'query':query,
                'no':no,
                'token':token,
                'pos':pos
            })
df_postagged = pd.DataFrame(postagged_list)
df_postagged.to_csv('data/naver_pos.csv', index=False, encoding='cp949')

# %% [markdown]
# # 3. 명사만 추출

# %%
import pandas as pd
df_postagged = pd.read_csv('data/naver_pos.csv', encoding='cp949')
df_postagged.head(1)
# Out:
#    query  no token pos
# 0  전주 여행   1    25  SN

# %%
select_pos = ['NNG', 'NNP'] # mecab의 명사 pos tag
df_nouns = df_postagged[df_postagged['pos'].isin(select_pos)]
df_nouns.to_csv('data/naver_pos_nouns.csv', index=False, encoding='cp949')

# %% [markdown]
# # 4. 빈도 분석
# - token 경주빈도 전주빈도 빈도합

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv', encoding='cp949')
df_nouns.head()
# Out:
#    query  no token  pos
# 0  전주 여행   1     곳  NNG
# 1  전주 여행   1    추천  NNG
# 2  전주 여행   1    부탁  NNG
# 3  전주 여행   1    아이  NNG
# 4  전주 여행   1    시점  NNG

# %%
df_nouns.groupby(['query','token'], as_index=False)['pos'].count()
# Out:
#       query token  pos
# 0     경주 여행    가격    5
# 1     경주 여행    가능   30
# 2     경주 여행  가보세요   10
# 3     경주 여행   가본적    5
# 4     경주 여행    가시    5
# ...     ...   ...  ...
# 996   전주 여행    효율    5
# 997   전주 여행     후    5
# 998   전주 여행    휴가    5
# 999   전주 여행    휴무    5
# 1000  전주 여행    흐노    5
#
# [1001 rows x 3 columns]

# %%
df_token_grp = df_nouns.groupby('query')['token'].value_counts()
df_token_grp = df_token_grp.reset_index(name='token_count')

# %%
df_token_grp.head()
# Out:
#    query token  token_count
# 0  경주 여행    코스          447
# 1  경주 여행    추천          424
# 2  경주 여행    계획          151
# 3  경주 여행     곳          134
# 4  경주 여행    맛집          133

# %%
df_gj = df_token_grp.loc[df_token_grp['query']=='경주 여행', ['token','token_count']]
df_jj = df_token_grp.loc[df_token_grp['query']=='전주 여행', ['token','token_count']]
df_gj.shape, df_jj.shape
# Out:
# ((535, 2), (466, 2))

# %%
df_gj.head()
# Out:
#   token  token_count
# 0    코스          447
# 1    추천          424
# 2    계획          151
# 3     곳          134
# 4    맛집          133

# %%
df_jj.head()
# Out:
#     token  token_count
# 535    코스          459
# 536     곳          433
# 537     봉          330
# 538    맛집          322
# 539    여수          315

# %%
#df_gj(경주 명사 출현횟수), df_jj(전주 명사 출현 횟수) 병합
import numpy as np
df_mrg = pd.merge(df_gj, df_jj, on='token', how='outer')
df_mrg.columns = ['token', '경주빈도', '전주빈도']
df_mrg.fillna(0, inplace=True)
df_mrg['경주빈도'] = df_mrg['경주빈도'].astype('int')
df_mrg['전주빈도'] = df_mrg['전주빈도'].astype(np.int32)
df_mrg.head(1)
# Out:
#   token  경주빈도  전주빈도
# 0    코스   447   459

# %%
df_mrg['빈도합'] = df_mrg['경주빈도']+df_mrg['전주빈도']
df_mrg['경주비율'] = df_mrg['경주빈도']/df_mrg['빈도합']
df_mrg['전주비율'] = df_mrg['전주빈도']/df_mrg['빈도합']
df_mrg['경주비율'] = df_mrg['경주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg['전주비율'] = df_mrg['전주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg.to_csv('data/naver_pos_nouns_count.csv', index=False, encoding='cp949')

# %% [markdown]
# # 5. 빈도 시각화(워드 클라우드, Text)
# - 전주 여행 워드클라우드/경주 여행 워드클라우드

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv', encoding='cp949')
df_nouns.loc[::1000]
# Out:
#        query   no token  pos
# 0      전주 여행    1     곳  NNG
# 1000   전주 여행   55    맛집  NNG
# 2000   전주 여행  112    추천  NNG
# 3000   전주 여행  163    예상  NNG
# 4000   전주 여행  220     달  NNG
# 5000   전주 여행  273    현대  NNG
# 6000   전주 여행  327  대중교통  NNG
# 7000   전주 여행  381    정도  NNG
# 8000   전주 여행  437    봉이  NNG
# 9000   전주 여행  490    전문  NNG
# 10000  경주 여행   54     지  NNG
# 11000  경주 여행  117   주차장  NNG
# 12000  경주 여행  185    가족  NNG
# 13000  경주 여행  246    반려  NNG
# 14000  경주 여행  311    추천  NNG
# 15000  경주 여행  377    추천  NNG
# 16000  경주 여행  440    계획  NNG

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query']=='경주 여행', 'token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query']=='전주 여행', 'token'].to_list()
gj_text = ' '.join(df_gj_noun_list)
jj_text = ' '.join(df_jj_noun_list)

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt
img = Image.open('data/heart.jpg')
mask = np.array(img)

wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf',
    background_color='white',
    colormap='Blues',
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex 황리길
    max_words=200,
    scale=2, # 이미지 크기의 비율(파일 저장시)
    mask=mask,
    contour_color='blue',
    contour_width=1
).generate(gj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_경주.jpg')

# %%
img = Image.open('data/korea-house-black-fill.png')
mask = np.array(img)

wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf',
    background_color='white',
    colormap='Blues',
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex 황리길
    max_words=200,
    scale=2, # 이미지 크기의 비율(파일 저장시)
    mask=mask,
    contour_color='blue',
    contour_width=1
).generate(jj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_전주.jpg')

# %% [markdown]
# ## 빈도수 시각화(nltk, Text)

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query']=='경주 여행', 'token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query']=='전주 여행', 'token'].to_list()

# %%
import nltk
data_text = nltk.Text(df_gj_noun_list)
plt.figure(figsize=(20,5))
plt.rc('font', family='Malgun Gothic')
data_text.plot(20)
plt.show()

# %%
word, counts = zip(*data_text.vocab().most_common(20))
# print(word)
# print(counts)
plt.figure(figsize=(20,5))
plt.plot(word, counts)
plt.xticks(rotation=30)
plt.xlabel('word')
plt.ylabel('count')
plt.title('경주 최빈 단어 빈도')
plt.show()

# %% [markdown]
# # 6. 유사도
# - Word2Vec

# %%
df = pd.read_csv('data/naver.csv')
df.sample()
# Out:
#      query   no             title  \
# 986  경주 여행  487   경주여행  추천 좀 해주세요
#
#                                                   link  \
# 986  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 986   가야하는 경주 여행 지도 추천 부탁합니다 경주보문단지내에 위치한 우양미술관은 국내...
#
#                                             total_text
# 986   경주여행  추천 좀 해주세요  가야하는 경주 여행 지도 추천 부탁합니다 경주보문단...

# %%
total_text_list = df['total_text'].to_list()
total_text_list[:2]
# Out:
# ['25년10월5,6,7일  전주여행   전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 ',
#  'KTX로 떠나는  전주 여행 , 주요 관광지 도보 이동...   전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 ']

# %%
from mecab import MeCab
select_pos = ['NNP', 'NNG']
불용어 = {'여행'}
analyzer = MeCab()
total_noun_list = []
for total_text in total_text_list:
    noun_list = [token for token, tag in analyzer.pos(total_text)
                    if tag in select_pos and
                        token not in 불용어 and
                        len(token)>1]
    total_noun_list.append(noun_list)
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(total_noun_list, window=10, min_count=2, workers=-1, 
                 sg=1) # 소량데이터

# %%
model.wv.most_similar('전주')
# Out:
# [('식사', 0.3595535457134247),
#  ('동선', 0.2897421419620514),
#  ('리스트', 0.275379478931427),
#  ('덕진구', 0.2731468081474304),
#  ('현재', 0.2580290138721466),
#  ('가격', 0.2295033037662506),
#  ('반려', 0.22023281455039978),
#  ('답변', 0.21883943676948547),
#  ('한옥마을', 0.21617142856121063),
#  ('허락', 0.2135322391986847)]

# %%
model.wv.most_similar('경주')
# Out:
# [('호수', 0.3641005754470825),
#  ('여름', 0.21867415308952332),
#  ('배차', 0.21632219851016998),
#  ('경기전', 0.2159893959760666),
#  ('인근', 0.21469099819660187),
#  ('황동', 0.2134207934141159),
#  ('다랭이', 0.20914912223815918),
#  ('봉길', 0.20906010270118713),
#  ('남편', 0.2070489227771759),
#  ('체계', 0.20607852935791016)]

# %% [markdown]
# # 연관분석

# %%
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
# %%time
from apyori import apriori
rules = apriori(total_noun_list, min_support=0.15, min_confidence=0.3, min_lift=1.01)
rules = list(rules)
len(rules)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 46.8 ms
# 125

# %%
import pandas as pd
rules_df = pd.DataFrame(None, columns=['lhs', 'rhs', '지지도','신뢰도', '향상도'])
idx = 0
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        #print(item)
        lhs = item[0]
        lhs = ','.join([x for x in lhs])
        rhs = item[1]
        rhs = ','.join([x for x in rhs])
        confidence = item[2]
        lift = item[3]
        rules_df.loc[idx] = [lhs, rhs, support, confidence, lift]
        idx += 1
#         print("{:10}=>{:16}\t{}\t{}\t{:.2f}".format(lhs, rhs, support, 
#                                                 round(confidence, 2), 
#                                                 lift))
rules_df = rules_df.sort_values(by=['신뢰도', '향상도'], ascending=False)
rules_df.head(20)
# Out:
#           lhs    rhs    지지도  신뢰도       향상도
# 102     국내,여수     티비  0.150  1.0  6.060606
# 132     국내,주달     티비  0.155  1.0  6.060606
# 138     국내,코스     티비  0.155  1.0  6.060606
# 162     맛집,여수     티비  0.155  1.0  6.060606
# 228     주달,여수     티비  0.155  1.0  6.060606
# 234     코스,여수     티비  0.155  1.0  6.060606
# 307     국내,여수  맛집,티비  0.150  1.0  6.060606
# 312  국내,맛집,여수     티비  0.150  1.0  6.060606
# 377     국내,주달  맛집,티비  0.155  1.0  6.060606
# 382  국내,맛집,주달     티비  0.155  1.0  6.060606
# 391     국내,코스  맛집,티비  0.155  1.0  6.060606
# 396  국내,맛집,코스     티비  0.155  1.0  6.060606
# 431     국내,여수  전주,티비  0.150  1.0  6.060606
# 437  국내,전주,여수     티비  0.150  1.0  6.060606
# 458     국내,여수  주달,티비  0.150  1.0  6.060606
# 464  국내,주달,여수     티비  0.150  1.0  6.060606
# 471     국내,여수  티비,코스  0.150  1.0  6.060606
# 477  국내,코스,여수     티비  0.150  1.0  6.060606
# 500     국내,주달  전주,티비  0.155  1.0  6.060606
# 505  국내,전주,주달     티비  0.155  1.0  6.060606
