# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense # 모델 layer 쌓을 때 필요
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])
# 2. 모델구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
               input_dim=2, # input_shape = (2,) # 입력 갯수
               activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 X
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석), 
            # categorical_crossentropy(다중분류-원핫인코딩을 한 경우)
            # sparse_categorical_crossentropy(다중분류-원핫인코딩을 안 한 경우)
model.compile(loss = 'binary_crossentropy',  # 손실함수(loss function)
             optimizer= 'adam',
             metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 20)                220
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist=model.fit(x_data, y_data, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 0.7063 - binary_accuracy: 0.5000 - 596ms/epoch - 596ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.7021 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.6981 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.6941 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6901 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6864 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6832 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6801 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6770 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6745 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6722 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6699 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6678 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6655 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6634 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6613 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6590 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6567 - binary_accuracy: 0.7500 - 998us/epoch - 998us/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6544 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6521 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6499 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6477 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6454 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6432 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6409 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6386 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6363 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6339 - binary_accuracy: 1.0000 - 36ms/epoch - 36ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6314 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6288 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6264 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6239 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6213 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6189 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6163 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6136 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6109 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6082 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6055 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6028 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6003 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.5979 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.5953 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.5927 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.5900 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.5872 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.5844 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.5818 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.5793 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.5767 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.5742 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.5716 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.5688 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.5661 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.5634 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.5607 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.5580 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.5552 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.5523 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.5495 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.5467 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.5441 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.5414 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.5386 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.5358 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.5330 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.5300 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.5271 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.5243 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.5214 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.5185 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.5155 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.5125 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.5095 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.5065 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.5035 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.5004 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.4973 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.4943 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.4912 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.4882 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.4852 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.4821 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.4790 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.4759 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.4728 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.4697 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.4666 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.4635 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.4603 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.4571 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.4540 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.4510 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.4479 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.4447 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.4415 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.4383 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.4352 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.4320 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.4288 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.4258 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.4227 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.4198 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.4168 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.4138 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.4106 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.4074 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.4042 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.4011 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.3980 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.3949 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.3918 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.3888 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.3858 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.3827 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.3798 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.3768 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.3737 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.3707 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.3677 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.3647 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.3617 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.3586 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.3557 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.3527 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.3497 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.3467 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.3437 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.3407 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.3378 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.3348 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.3318 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.3289 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.3259 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.3230 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.3200 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.3171 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.3141 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.3111 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.3082 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.3052 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.3023 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.2994 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.2966 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.2937 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.2909 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.2882 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.2854 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.2826 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.2797 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.2769 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.2741 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.2713 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.2685 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.2657 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.2629 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.2601 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.2573 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.2546 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.2520 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.2492 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.2465 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.2438 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.2411 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.2385 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.2359 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.2333 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.2306 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.2280 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.2253 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.2227 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.2200 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.2175 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.2149 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.2123 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.2098 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.2073 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.2048 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.2023 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.1998 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.1973 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.1948 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.1923 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.1898 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.1874 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.1850 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.1827 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.1803 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.1778 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.1755 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.1731 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.1708 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.1684 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.1662 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.1639 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.1616 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.1594 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.1571 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.1550 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.1527 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.1506 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.1484 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.1462 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.1441 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.1421 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.1400 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.1379 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.1359 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.1339 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.1319 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.1299 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.1279 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.1260 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.1241 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.1222 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.1203 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.1184 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.1166 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.1148 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.1131 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.1113 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.1096 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.1079 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.1062 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.1045 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.1029 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.1014 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.0998 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.0982 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.0967 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.0951 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.0936 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.0921 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.0906 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.0892 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.0878 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.0864 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.0850 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.0836 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.0823 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.0809 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.0796 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.0784 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.0771 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.0759 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.0747 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.0735 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.0723 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.0711 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.0700 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.0689 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.0678 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.0667 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.0657 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.0646 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.0636 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.0626 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.0616 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.0607 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.0597 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.0588 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.0579 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.0570 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.0561 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.0553 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.0544 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.0536 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.0528 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.0520 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.0512 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.0504 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.0496 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.0489 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.0482 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.0475 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.0468 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.0461 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.0454 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.0447 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.0441 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.0434 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.0428 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.0422 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.0416 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.0410 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.0404 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.0398 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.0392 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.0387 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.0381 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.0376 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.0371 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.0365 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.0361 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.0355 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.0350 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.0346 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.0341 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.0336 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.0332 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step

# %%
# 5. 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score=model.evaluate(x_data, y_data) #
score
# Out:
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0327 - binary_accuracy: 1.0000
# [0.0327029749751091, 1.0]

# %%
# 모델 평가하기
score=model.evaluate(x_data, y_data) #
print('loss:', score[0])
print('accuracy:',score[1])
# Out:
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0327 - binary_accuracy: 1.0000
# loss: 0.0327029749751091
# accuracy: 1.0

# %%
 # 예측하기
model.predict(np.array([[0, 1]]))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[0.9924195]], dtype=float32)
